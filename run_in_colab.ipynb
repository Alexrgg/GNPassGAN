# %%
import google.colab

google.colab.drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
### TRAINING PARAMETERS ###

#training_data='/content/drive/Othercomputers/My MacBook Pro/PassGAN_data/train_reduce.txt'
training_data='./data/test_rockyou812.txt'
output_dir='../PassGAN_data/GNPassGAN_12-02-2023'
n_iters=20000

# %%
# !python3 './models.py' --training-data '{training_data}'  --output-dir '{output_dir}' --iters '{n_iters}'
# Out:
# /Users/alejandrorodriguez/Library/Python/3.8/lib/python/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
#
#
# Cuda Is Avaible False.
#
#
# Uppercase local vars:
# 	F: <module 'torch.nn.functional' from '/Users/alejandrorodriguez/Library/Python/3.8/lib/python/site-packages/torch/nn/functional.py'>
# loaded 2109188 lines in dataset
# Number of unique characters in dataset: 368
# Generator(
#   (fc1): Linear(in_features=128, out_features=1536, bias=True)
#   (block): Sequential(
#     (0): ResBlock(
#       (res_block): Sequential(
#         (0): ReLU(inplace=True)
#         (1): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,))
#         (2): ReLU(inplace=True)
#         (3): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,))
#       )
#     )
#     (1): ResBlock(
# ...

# %% [markdown]
# Ha tardado 17h para un dataset de 2000 palabras.
#
# Pra las 200.000 iteraciones con el dataset del github por defecto tardaría en entrenar 3.5 días, 1.5s por iteración

# %%
### GENERATION PARAMETERS ###
#model_trained_dir='/content/drive/Othercomputers/My MacBook Pro/PassGAN_data/GNPassGAN_28-01-2023'
model_trained_dir='../PassGAN_data/GNPassGAN_28-01-2023'
#model_trained_dir='../PassGAN_data/GNPassGAN_12-02-2023'
generated_passwords=model_trained_dir+'/generated_GNPassGAN.txt'
password_length=12
n_passwords=10000
n_trained_iters=10000

# %%
# !python3 './sample.py' --input-dir '{model_trained_dir}' --output '{generated_passwords}' --seq-length '{password_length}' --num-samples '{n_passwords}' --training-iters '{n_trained_iters}'
# Out:
# /Users/alejandrorodriguez/Library/Python/3.8/lib/python/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Traceback (most recent call last):
#   File "./sample.py", line 166, in <module>
#     netG.load_state_dict(torch.load(f'output/checkpoints/netG_epoch_{args.training_iters}.pth',map_location=torch.device('cpu')))
#   File "/Users/alejandrorodriguez/Library/Python/3.8/lib/python/site-packages/torch/nn/modules/module.py", line 1482, in load_state_dict
#     raise RuntimeError('Error(s) in loading state_dict for {}:\n\t{}'.format(
# RuntimeError: Error(s) in loading state_dict for Generator:
# 	size mismatch for conv1.weight: copying a param with shape torch.Size([548, 128, 1]) from checkpoint, the shape in current model is torch.Size([82, 128, 1]).
# ...

# %%
print(f"python3 ./sample.py --input-dir '{model_trained_dir}' --output '{generated_passwords}' --seq-length {password_length} --num-samples {n_passwords} --training-iters {n_trained_iters}")
# Out:
# python3 ./sample.py --input-dir '../PassGAN_data/GNPassGAN_28-01-2023' --output '../PassGAN_data/GNPassGAN_28-01-2023/generated_GNPassGAN.txt' --seq-length 12 --num-samples 1000 --training-iters 20000

# %%
python3 sample.py \
--input-dir output \
--output ../generated_GNPassGAN.txt \
--seq-length 12 \
--num-samples 1000000
